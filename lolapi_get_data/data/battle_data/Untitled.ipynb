# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorboard.plugins import projector
from sklearn.model_selection import train_test_split

from tensorflow.keras import backend as K
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))
import csv
import os

f = open("DIAMOND_I_10_data.csv")
rdr = csv.reader(f)
r = list(rdr)

# %%
r[3:]
# Out:
# [['2',
#   'TFT6_Augment_TinyTitans',
#   'TFT6_Augment_Electrocharge1',
#   'TFT6_Augment_CyberneticUplink2',
#   '1',
#   "['TFT7_Leona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yone', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'TFT_Item_ZekesHerald', 'TFT_Item_IonicSpark', 'TFT_Item_RedBuff']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_Redemption', 'TFT7_Item_MirageEmblemItem', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_ArchangelsStaff', 'TFT_Item_ArchangelsStaff']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_RapidFireCannon', 'TFT_Item_Redemption', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Soraka', 2, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['3',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   'TFT7_Augment_DragonHorde',
#   'TFT7_Augment_RevelPartyFavors',
#   '5',
#   "['TFT7_Lulu', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_TitansResolve', 'TFT_Item_Bloodthirster', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_StatikkShiv', 'TFT_Item_Quicksilver']",
#   "['TFT7_DragonGold', 1, 'TFT7_Item_ShimmerscaleMogulsMail', 'TFT_Item_WarmogsArmor', 'TFT_Item_Redemption']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_UnstableConcoction', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['4',
#   'TFT6_Augment_SecondWind2',
#   'TFT6_Augment_Ascension',
#   'TFT6_Augment_PortableForge',
#   '7',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Braum', 2, 'TFT_Item_TitansResolve', 'TFT_Item_RedBuff', 'TFT4_Item_OrnnDeathsDefiance']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT_Item_GuinsoosRageblade', 'noItems', 'noItems']",
#   "['TFT7_Sona', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_Bloodthirster', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 3, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['5',
#   'TFT7_Augment_Bloodlust1',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   'TFT6_Augment_ComponentGrabBag',
#   '3',
#   "['TFT7_Nidalee', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Deathblade', 'TFT_Item_Quicksilver']",
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_RedBuff', 'TFT_Item_WarmogsArmor', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_ZekesHerald', 'noItems', 'noItems']",
#   "['TFT7_Shyvana', 2, 'TFT_Item_HextechGunblade', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 2, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['6',
#   'TFT7_Augment_MageTrait',
#   'TFT6_Augment_BlueBattery2',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   '5',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff', 'TFT_Item_GargoyleStoneplate']",
#   "['TFT7_Ornn', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'TFT_Item_Shroud', 'TFT_Item_HextechGunblade', 'noItems']",
#   "['TFT7_AurelionSol', 1, 'TFT_Item_JeweledGauntlet', 'TFT_Item_SpearOfShojin', 'TFT_Item_InfinityEdge']",
#   "['TFT7_TrainerDragon', 3, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['7',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT6_Augment_RichGetRicherPlus',
#   'TFT6_Augment_ForceOfNature',
#   '3',
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Volibear', 2, 'TFT_Item_Chalice', 'TFT_Item_ZekesHerald', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT_Item_ArchangelsStaff', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_DragonsClaw', 'TFT_Item_WarmogsArmor', 'TFT_Item_BrambleVest']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_Bloodthirster', 'TFT7_Item_LegendEmblemItem', 'TFT_Item_TitansResolve']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_ThiefsGloves', 'TFT_Item_Chalice', 'TFT_Item_GargoyleStoneplate']",
#   "['TFT7_Bard', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['8',
#   'TFT6_Augment_Weakspot',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT7_Augment_ThinkFast',
#   '1',
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_TitanicHydra', 'noItems', 'noItems']",
#   "['TFT7_Talon', 2, 'TFT_Item_ThiefsGloves', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'TFT_Item_InfinityEdge', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_GuardianAngel']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_Quicksilver', 'TFT7_Item_CavalierEmblemItem', 'noItems']",
#   "['TFT7_Shyvana', 2, 'TFT_Item_IonicSpark', 'TFT_Item_TitansResolve', 'TFT_Item_WarmogsArmor']",
#   '',
#   '',
#   '',
#   ''],
#  ['9',
#   'TFT7_Augment_EvokerTrait',
#   'TFT6_Augment_TinyTitans',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   '2',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT_Item_Chalice', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 1, 'TFT_Item_ThiefsGloves', 'TFT_Item_PowerGauntlet', 'TFT_Item_LastWhisper']",
#   "['TFT7_Hecarim', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ornn', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_MadredsBloodrazor', 'noItems']",
#   "['TFT7_Zoe', 2, 'TFT_Item_LocketOfTheIronSolari', 'TFT_Item_GuardianAngel', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_AoShin', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['10',
#   'TFT6_Augment_Weakspot',
#   'TFT6_Augment_PortableForge',
#   'TFT6_Augment_TomeOfTraits1',
#   '5',
#   "['TFT7_Sett', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Karma', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_LeeSin', 2, 'TFT_Item_DragonsClaw', 'TFT_Item_BrambleVest', 'noItems']",
#   "['TFT7_Volibear', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver']",
#   "['TFT7_Anivia', 2, 'TFT4_Item_OrnnMuramana', 'TFT_Item_ArchangelsStaff', 'TFT_Item_StatikkShiv']",
#   "['TFT7_Ornn', 1, 'TFT7_Item_DragonmancerEmblemItem', 'TFT_Item_Bloodthirster', 'TFT_Item_JeweledGauntlet']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['11',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   'TFT6_Augment_MakeshiftArmor1',
#   'TFT6_Augment_SunfireBoard',
#   '6',
#   "['TFT7_Vladimir', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Skarner', 3, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Nidalee', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Varus', 3, 'TFT_Item_Quicksilver', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Illaoi', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AurelionSol', 1, 'TFT_Item_ArchangelsStaff', 'TFT_Item_Quicksilver', 'TFT_Item_HextechGunblade']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['12',
#   'TFT6_Augment_MaxLevel10',
#   'TFT6_Augment_Recombobulator',
#   'TFT6_Augment_CelestialBlessing3',
#   '8',
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_InfinityEdge', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Ornn', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade', 'noItems']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 1, 'TFT_Item_ArchangelsStaff', 'TFT_Item_JeweledGauntlet', 'TFT_Item_HextechGunblade']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['13',
#   'TFT7_Augment_UrfsGrabBag1',
#   'TFT6_Augment_RichGetRicherPlus',
#   'TFT6_Augment_PortableForge',
#   '5',
#   "['TFT7_Thresh', 2, 'TFT7_Item_ShimmerscaleEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Kayn', 2, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Volibear', 2, 'TFT7_Item_ShimmerscaleHeartOfGold', 'noItems', 'noItems']",
#   "['TFT7_DragonGold', 1, 'TFT4_Item_OrnnAnimaVisage', 'TFT7_Item_ShimmerscaleMogulsMail', 'TFT_Item_GargoyleStoneplate']",
#   "['TFT7_Zoe', 1, 'TFT7_Item_ShimmerscaleCrownOfChampions', 'TFT_Item_GuinsoosRageblade', 'TFT7_Item_ShimmerscaleGamblersBlade']",
#   "['TFT7_Yasuo', 1, 'TFT7_Item_ShimmerscaleEmblemItem', 'TFT7_Item_ShimmerscaleDeterminedInvestor', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT7_Item_ShimmerscaleEmblemItem', 'TFT_Item_StatikkShiv', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['14',
#   'TFT6_Augment_SunfireBoard',
#   'TFT6_Augment_TargetDummies',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   '7',
#   "['TFT7_Thresh', 1, 'TFT7_Item_ShimmerscaleHeartOfGold', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_LastWhisper', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT_Item_UnstableConcoction', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Sona', 1, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_DragonGold', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_Shroud', 'TFT_Item_IonicSpark']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['15',
#   'TFT6_Augment_TinyTitans',
#   'TFT7_Augment_MageEmblem',
#   'TFT6_Augment_SecondWind2',
#   '1',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_LastWhisper', 'TFT_Item_RunaansHurricane', 'TFT_Item_InfinityEdge']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Bloodthirster', 'TFT_Item_InfinityEdge']",
#   "['TFT7_Sona', 2, 'TFT7_Item_MageEmblemItem', 'TFT_Item_UnstableConcoction', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT7_Item_RevelEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'TFT_Item_RapidFireCannon', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['16',
#   'TFT7_Augment_CavalierEmblem',
#   'TFT6_Augment_Diversify2',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   '3',
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Qiyana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT7_Item_CavalierEmblemItem', 'TFT_Item_ArchangelsStaff', 'TFT_Item_ChainVest']",
#   "['TFT7_Twitch', 2, 'TFT_Item_ZekesHerald', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_RedBuff', 'TFT_Item_WarmogsArmor', 'TFT_Item_DragonsClaw']",
#   "['TFT7_Talon', 2, 'TFT_Item_JeweledGauntlet', 'TFT7_Item_CavalierEmblemItem', 'TFT_Item_Quicksilver']",
#   "['TFT7_Xayah', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Ornn', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_RunaansHurricane', 'TFT_Item_SeraphsEmbrace']",
#   '',
#   '',
#   '',
#   ''],
#  ['17',
#   'TFT6_Augment_Weakspot',
#   'TFT6_Augment_Ascension',
#   'TFT7_Augment_CannoneerEmblem2',
#   '4',
#   "['TFT7_Thresh', 2, 'TFT_Item_IonicSpark', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_RunaansHurricane', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_RunaansHurricane']",
#   "['TFT7_Lulu', 2, 'TFT_Item_SpearOfShojin', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT7_Item_ShimmerscaleGoldmancersStaff', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Sona', 2, 'TFT7_Item_CannoneerEmblemItem', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_DragonGold', 2, 'TFT_Item_BrambleVest', 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['18',
#   'TFT7_Augment_Preparation2',
#   'TFT6_Augment_ForceOfNature',
#   'TFT6_Augment_SecondWind2',
#   '8',
#   "['TFT7_Thresh', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Jinx', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Braum', 3, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_WarmogsArmor', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 1, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_Sona', 1, 'TFT_Item_ArchangelsStaff', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'TFT_Item_NeedlesslyLargeRod', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 3, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['19',
#   'TFT6_Augment_Ascension',
#   'TFT6_Augment_CelestialBlessing3',
#   'TFT6_Augment_BlueBattery2',
#   '4',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT_Item_RedBuff', 'TFT_Item_WarmogsArmor', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Illaoi', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT_Item_LastWhisper', 'TFT_Item_MadredsBloodrazor', 'noItems']",
#   "['TFT7_Sona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_Bloodthirster', 'TFT_Item_UnstableConcoction', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['20',
#   'TFT6_Augment_SunfireBoard',
#   'TFT7_Augment_PandorasBench',
#   'TFT6_Augment_PortableForge',
#   '8',
#   "['TFT7_Leona', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yone', 1, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_WarmogsArmor', 'TFT4_Item_OrnnDeathsDefiance']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_GuardianAngel', 'TFT_Item_Redemption']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_ArchangelsStaff', 'TFT_Item_JeweledGauntlet']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['21',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT6_Augment_Featherweights1',
#   'TFT6_Augment_Weakspot',
#   '3',
#   "['TFT7_Leona', 3, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Yone', 3, 'TFT_Item_Bloodthirster', 'TFT_Item_Quicksilver', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Shen', 3, 'TFT_Item_ZekesHerald', 'noItems', 'noItems']",
#   "['TFT7_Braum', 3, 'TFT_Item_BrambleVest', 'TFT_Item_Bloodthirster', 'TFT_Item_Quicksilver']",
#   "['TFT7_Olaf', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_ZekesHerald', 'TFT_Item_Deathblade']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_Chalice', 'noItems', 'noItems']",
#   "['TFT7_Bard', 2, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['22',
#   'TFT6_Augment_PandorasItems',
#   'TFT6_Augment_FuturePeepers2',
#   'TFT6_Augment_CelestialBlessing3',
#   '2',
#   "['TFT7_Heimerdinger', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Illaoi', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_RedBuff']",
#   "['TFT7_Ornn', 1, 'TFT_Item_TitanicHydra', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT5_Item_RabadonsDeathcapRadiant', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_ArchangelsStaff']",
#   "['TFT7_Zoe', 2, 'TFT_Item_PowerGauntlet', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_BrambleVest', 'TFT_Item_TitansResolve', 'TFT_Item_Redemption']",
#   "['TFT7_Bard', 2, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 2, 'TFT7_Item_MageEmblemItem', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['23',
#   'TFT7_Augment_Bloodlust1',
#   'TFT6_Augment_Meditation1',
#   'TFT6_Augment_JeweledLotus',
#   '6',
#   "['TFT7_Vladimir', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_IonicSpark', 'TFT_Item_RedBuff']",
#   "['TFT7_Illaoi', 2, 'TFT_Item_GargoyleStoneplate', 'noItems', 'noItems']",
#   "['TFT7_AurelionSol', 1, 'TFT_Item_Quicksilver', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['24',
#   'TFT6_Augment_SunfireBoard',
#   'TFT6_Augment_LudensEcho2',
#   'TFT6_Augment_BlueBattery2',
#   '6',
#   "['TFT7_Jinx', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Braum', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT_Item_ZekesHerald', 'TFT_Item_Chalice', 'noItems']",
#   "['TFT7_Corki', 1, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_UnstableConcoction', 'TFT_Item_LastWhisper']",
#   "['TFT7_Sona', 1, 'TFT_Item_JeweledGauntlet', 'noItems', 'noItems']",
#   "['TFT7_DragonGold', 2, 'TFT7_Item_ShimmerscaleMogulsMail', 'TFT_Item_TitanicHydra', 'noItems']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['25',
#   'TFT7_Augment_RevelTrait',
#   'TFT7_Augment_DragonHorde',
#   'TFT6_Augment_MaxLevel10',
#   '7',
#   "['TFT7_TahmKench', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_JeweledGauntlet', 'TFT_Item_InfinityEdge', 'TFT_Item_ArchangelsStaff']",
#   "['TFT7_Sona', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_Morellonomicon', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_DragonGold', 1, 'TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_RedBuff', 'TFT_Item_NegatronCloak']",
#   "['TFT7_Yasuo', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Pyke', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['26',
#   'TFT6_Augment_TinyTitans',
#   'TFT7_Augment_CavalierTrait',
#   'TFT6_Augment_TheGoldenEgg',
#   '2',
#   "['TFT7_Yone', 2, 'TFT_Item_GuardianAngel', 'TFT_Item_FrozenHeart', 'noItems']",
#   "['TFT7_Lillia', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 3, 'TFT_Item_Bloodthirster', 'TFT5_Item_JeweledGauntletRadiant', 'TFT_Item_RedBuff']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_FrozenHeart', 'TFT_Item_RapidFireCannon']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_HextechGunblade', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_Quicksilver', 'TFT4_Item_OrnnMuramana', 'TFT_Item_MadredsBloodrazor']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['27',
#   'TFT7_Augment_BestFriends1',
#   'TFT6_Augment_FirstAidKit',
#   'TFT6_Augment_PortableForge',
#   '4',
#   "['TFT7_Sett', 3, 'TFT4_Item_OrnnInfinityForce', 'TFT_Item_UnstableConcoction', 'TFT_Item_Quicksilver']",
#   "['TFT7_Kayn', 2, 'TFT_Item_RedBuff', 'TFT_Item_IonicSpark', 'noItems']",
#   "['TFT7_Shen', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 1, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'TFT_Item_InfinityEdge', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shyvana', 2, 'TFT_Item_JeweledGauntlet', 'TFT_Item_TitansResolve', 'TFT_Item_InfinityEdge']",
#   '',
#   '',
#   '',
#   ''],
#  ['28',
#   'TFT6_Augment_ForceOfNature',
#   'TFT6_Augment_SecondWind1',
#   'TFT6_Augment_ItemGrabBag2',
#   '3',
#   "['TFT7_Lulu', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_Chalice', 'noItems']",
#   "['TFT7_Ryze', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_DragonsClaw', 'TFT_Item_Deathblade']",
#   "['TFT7_Ornn', 2, 'TFT_Item_Redemption', 'TFT_Item_BrambleVest', 'TFT_Item_WarmogsArmor']",
#   "['TFT7_Zoe', 1, 'TFT_Item_ThiefsGloves', 'TFT_Item_UnstableConcoction', 'TFT_Item_Zephyr']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_UnstableConcoction', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_Bard', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_SpearOfShojin', 'TFT_Item_HextechGunblade']",
#   '',
#   '',
#   '',
#   ''],
#  ['29',
#   'TFT6_Augment_JeweledLotus',
#   'TFT6_Augment_PandorasItems',
#   'TFT6_Augment_TomeOfTraits1',
#   '8',
#   "['TFT7_Kayn', 2, 'TFT7_Item_ShimmerscaleDravensAxe', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_Spatula', 'TFT7_Item_ShimmerscaleEmblemItem', 'noItems']",
#   "['TFT7_LeeSin', 2, 'TFT7_Item_ShimmerscaleEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Volibear', 1, 'TFT7_Item_ShimmerscaleDeterminedInvestor', 'noItems', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT7_Item_ShimmerscaleGoldmancersStaff', 'TFT_Item_TearOfTheGoddess', 'noItems']",
#   "['TFT7_DragonGold', 1, 'TFT7_Item_ShimmerscaleHeartOfGold', 'TFT_Item_GargoyleStoneplate', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['30',
#   'TFT6_Augment_MetabolicAccelerator',
#   'TFT7_Augment_PandorasBench',
#   'TFT6_Augment_ComponentGrabBag',
#   '8',
#   "['TFT7_Sett', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_Quicksilver']",
#   "['TFT7_Senna', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Kayn', 2, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT_Item_ZekesHerald', 'TFT_Item_ZekesHerald', 'TFT_Item_ZekesHerald']",
#   "['TFT7_LeeSin', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'TFT_Item_JeweledGauntlet', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 1, 'TFT_Item_NeedlesslyLargeRod', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['31',
#   'TFT7_Augment_Bloodlust1',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT7_Augment_RagewingEmblem',
#   '7',
#   "['TFT7_Sett', 3, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver']",
#   "['TFT7_Thresh', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Kayn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT_Item_Redemption', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 1, 'TFT_Item_MadredsBloodrazor', 'noItems', 'noItems']",
#   "['TFT7_DragonPurple', 1, 'TFT7_Item_RagewingEmblemItem', 'TFT_Item_Bloodthirster', 'TFT_Item_ArchangelsStaff']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['32',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT7_Augment_DragonHorde',
#   'TFT6_Augment_GrandGambler',
#   '7',
#   "['TFT7_Kayn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Volibear', 3, 'TFT_Item_InfinityEdge', 'TFT_Item_UnstableConcoction', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Xayah', 1, 'TFT7_Item_ShimmerscaleDravensAxe', 'TFT7_Item_ShimmerscaleGamblersBlade', 'TFT_Item_Quicksilver']",
#   "['TFT7_DragonGold', 1, 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff', 'TFT_Item_BrambleVest']",
#   "['TFT7_Shyvana', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['33',
#   'TFT7_Augment_SwiftshotEmblem',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT7_Augment_JadeTrait',
#   '8',
#   "['TFT7_Taric', 3, 'TFT_Item_IonicSpark', 'TFT_Item_GuardianAngel', 'TFT7_Item_SwiftshotEmblemItem']",
#   "['TFT7_Ashe', 2, 'TFT_Item_RunaansHurricane', 'TFT_Item_InfinityEdge', 'TFT_Item_RapidFireCannon']",
#   "['TFT7_AoShin', 1, 'TFT_Item_Spatula', 'noItems', 'noItems']",
#   "['TFT7_AurelionSol', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT_Item_ChainVest', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['34',
#   'TFT7_Augment_JadePenitence',
#   'TFT7_Augment_DragonmancerEmblem',
#   'TFT6_Augment_MaxLevel10',
#   '3',
#   "['TFT7_Karma', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Taric', 2, 'TFT7_Item_DragonmancerEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_HextechGunblade', 'TFT_Item_NeedlesslyLargeRod']",
#   "['TFT7_Neeko', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_Redemption', 'TFT_Item_LocketOfTheIronSolari']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_InfinityEdge', 'TFT_Item_JeweledGauntlet', 'TFT_Item_TitansResolve']",
#   "['TFT7_Soraka', 2, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['35',
#   'TFT7_Augment_Preparation',
#   'TFT6_Augment_ThriftShop',
#   'TFT6_Augment_ItemGrabBag2',
#   '5',
#   "['TFT7_Sett', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_TitansResolve', 'TFT_Item_Quicksilver']",
#   "['TFT7_Kayn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 3, 'TFT_Item_WarmogsArmor', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_BrambleVest']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_Morellonomicon', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'TFT_Item_LastWhisper', 'TFT_Item_SparringGloves', 'noItems']",
#   "['TFT7_Shyvana', 1, 'TFT_Item_Redemption', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['36',
#   'TFT7_Augment_AxiomArc1',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT6_Augment_HighEndShopping',
#   '4',
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Neeko', 1, 'TFT_Item_RedBuff', 'TFT_Item_FrozenHeart', 'TFT_Item_BrambleVest']",
#   "['TFT7_Sona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Bard', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shyvana', 2, 'TFT_Item_JeweledGauntlet', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_TitansResolve']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['37',
#   'TFT6_Augment_LudensEcho1',
#   'TFT7_Augment_EvokerTrait',
#   'TFT6_Augment_SecondWind2',
#   '6',
#   "['TFT7_Jinx', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT_Item_ZekesHerald', 'TFT_Item_LocketOfTheIronSolari', 'noItems']",
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 1, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_UnstableConcoction']",
#   "['TFT7_Neeko', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'TFT_Item_GuardianAngel', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['38',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT7_Augment_Preparation2',
#   'TFT6_Augment_CyberneticUplink2',
#   '7',
#   "['TFT7_Vladimir', 3, 'TFT_Item_ThiefsGloves', 'TFT_Item_Quicksilver', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Skarner', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nidalee', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 3, 'TFT_Item_PowerGauntlet', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Varus', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_InfinityEdge', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Illaoi', 3, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_PowerGauntlet', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['39',
#   'TFT6_Augment_LudensEcho2',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT6_Augment_HighEndShopping',
#   '1',
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_Zephyr', 'noItems']",
#   "['TFT7_Yasuo', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_Bloodthirster', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Bard', 2, 'TFT7_Item_DragonmancerEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_AurelionSol', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_ArchangelsStaff', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Soraka', 2, 'TFT_Item_SpearOfShojin', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['40',
#   'TFT7_Augment_JadeEternalProtection',
#   'TFT6_Augment_FirstAidKit',
#   'TFT6_Augment_JeweledLotus',
#   '2',
#   "['TFT7_Gnar', 2, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_FrozenHeart', 'TFT_Item_RedBuff', 'TFT_Item_DragonsClaw']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_UnstableConcoction', 'TFT_Item_RapidFireCannon']",
#   "['TFT7_Sona', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_UnstableConcoction', 'noItems', 'noItems']",
#   "['TFT7_Bard', 2, 'TFT_Item_SpearOfShojin', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 2, 'TFT_Item_NeedlesslyLargeRod', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['41',
#   'TFT6_Augment_CyberneticUplink1',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT6_Augment_JeweledLotus',
#   '2',
#   "['TFT7_Karma', 2, 'TFT_Item_Chalice', 'noItems', 'noItems']",
#   "['TFT7_Gnar', 2, 'TFT7_Item_ShimmerscaleEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_BFSword', 'noItems', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT_Item_Morellonomicon', 'TFT_Item_ArchangelsStaff', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Neeko', 2, 'TFT_Item_Redemption', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_TitansResolve', 'TFT_Item_UnstableConcoction', 'TFT_Item_GuardianAngel']",
#   "['TFT7_Soraka', 1, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['42',
#   'TFT6_Augment_BandOfThieves2',
#   'TFT7_Augment_MageEmblem',
#   'TFT6_Augment_Ascension',
#   '4',
#   "['TFT7_Vladimir', 2, 'TFT_Item_GiantsBelt', 'noItems', 'noItems']",
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 3, 'TFT_Item_ThiefsGloves', 'TFT_Item_RecurveBow', 'TFT_Item_Deathblade']",
#   "['TFT7_Lulu', 2, 'TFT7_Item_MageEmblemItem', 'TFT_Item_GuardianAngel', 'noItems']",
#   "['TFT7_Ryze', 3, 'TFT_Item_ArchangelsStaff', 'TFT_Item_SpearOfShojin', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Sylas', 2, 'TFT_Item_TitansResolve', 'TFT_Item_DragonsClaw', 'TFT_Item_WarmogsArmor']",
#   "['TFT7_Illaoi', 3, 'TFT_Item_ThiefsGloves', 'TFT_Item_ZekesHerald', 'TFT_Item_Deathblade']",
#   "['TFT7_TrainerDragon', 1, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['43',
#   'TFT6_Augment_PandorasItems',
#   'TFT7_Augment_AxiomArc1',
#   'TFT6_Augment_CelestialBlessing2',
#   '7',
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 3, 'TFT_Item_RedBuff', 'TFT_Item_IonicSpark', 'TFT_Item_WarmogsArmor']",
#   "['TFT7_Ryze', 1, 'TFT7_Item_CavalierEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 1, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_JeweledGauntlet', 'TFT_Item_InfinityEdge']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['44',
#   'TFT6_Augment_JeweledLotus',
#   'TFT7_Augment_EvokerEmblem2',
#   'TFT7_Augment_EvokerEssenceTheft',
#   '1',
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_InfinityEdge', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Neeko', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_RapidFireCannon', 'TFT_Item_GargoyleStoneplate']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_TitansResolve', 'TFT_Item_Bloodthirster', 'TFT_Item_LastWhisper']",
#   "['TFT7_Sona', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_Morellonomicon', 'TFT_Item_StatikkShiv']",
#   "['TFT7_Zoe', 1, 'TFT7_Item_EvokerEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['45',
#   'TFT6_Augment_RichGetRicher',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT7_Augment_UrfsGrabBag1',
#   '7',
#   "['TFT7_Sett', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Senna', 3, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 2, 'TFT7_Item_RagewingEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_FrozenHeart', 'TFT_Item_Bloodthirster', 'TFT_Item_WarmogsArmor']",
#   "['TFT7_Hecarim', 1, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 1, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver', 'TFT_Item_TitansResolve']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['46',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT6_Augment_Meditation2',
#   '2',
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_StatikkShiv', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Lulu', 2, 'TFT_Item_Shroud', 'TFT_Item_ZekesHerald', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_RedBuff', 'TFT_Item_Shroud', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'TFT_Item_InfinityEdge', 'TFT_Item_TitansResolve', 'TFT_Item_Bloodthirster']",
#   "['TFT7_Sona', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_ZekesHerald', 'TFT_Item_ZekesHerald']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['47',
#   'TFT6_Augment_CyberneticUplink1',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT6_Augment_CelestialBlessing2',
#   '5',
#   "['TFT7_Vladimir', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Heimerdinger', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 1, 'TFT_Item_PowerGauntlet', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_IonicSpark', 'TFT_Item_RedBuff']",
#   "['TFT7_Ornn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 1, 'TFT_Item_JeweledGauntlet', 'TFT_Item_SpearOfShojin', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_TrainerDragon', 1, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['48',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   'TFT7_Augment_BestFriends1',
#   'TFT6_Augment_SecondWind2',
#   '1',
#   "['TFT7_Leona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yone', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 2, 'TFT_Item_SeraphsEmbrace', 'TFT_Item_ChainVest', 'TFT_Item_GuardianAngel']",
#   "['TFT7_Nunu', 2, 'TFT_Item_IonicSpark', 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_Quicksilver', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_HextechGunblade', 'TFT_Item_UnstableConcoction', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['49',
#   'TFT7_Augment_TomeOfTraits2',
#   'TFT6_Augment_CyberneticImplants1',
#   'TFT6_Augment_RadiantRelics',
#   '4',
#   "['TFT7_TahmKench', 2, 'TFT_Item_ChainVest', 'noItems', 'noItems']",
#   "['TFT7_Jinx', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_LastWhisper']",
#   "['TFT7_Lulu', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_JeweledGauntlet', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Corki', 2, 'TFT_Item_JeweledGauntlet', 'TFT_Item_HextechGunblade', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_Ornn', 2, 'TFT5_Item_SunfireCapeRadiant', 'TFT_Item_GargoyleStoneplate', 'noItems']",
#   "['TFT7_Sona', 2, 'TFT7_Item_CannoneerEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'TFT_Item_SpearOfShojin', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT7_Item_TempestEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   ''],
#  ['50',
#   'TFT7_Augment_MikaelsGift',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT7_Augment_AxiomArc2',
#   '3',
#   "['TFT7_Qiyana', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Shen', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_LocketOfTheIronSolari', 'TFT_Item_LocketOfTheIronSolari', 'TFT_Item_LocketOfTheIronSolari']",
#   "['TFT7_Talon', 2, 'TFT_Item_Shroud', 'TFT_Item_SparringGloves', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'TFT_Item_UnstableConcoction', 'TFT_Item_InfinityEdge', 'TFT_Item_TitansResolve']",
#   "['TFT7_Ornn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_SpearOfShojin', 'TFT_Item_WarmogsArmor', 'TFT_Item_StatikkShiv']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['51',
#   'TFT7_Augment_GadgetExpert',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT6_Augment_CyberneticImplants2',
#   '3',
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_RedBuff', 'TFT_Item_WarmogsArmor', 'TFT_Item_Zephyr']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_TitansResolve', 'TFT_Item_GuardianAngel', 'TFT_Item_Bloodthirster']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_TitansResolve', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Bard', 1, 'TFT_Item_StatikkShiv', 'TFT_Item_NeedlesslyLargeRod', 'noItems']",
#   "['TFT7_Soraka', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_Redemption', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['52',
#   'TFT6_Augment_TomeOfTraits1',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT7_Augment_WhispersEmblem2',
#   '7',
#   "['TFT7_Thresh', 2, 'TFT_Item_ZekesHerald', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'TFT7_Item_WhispersEmblemItem', 'TFT_Item_TitanicHydra', 'TFT_Item_TitanicHydra']",
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ornn', 1, 'TFT_Item_TitansResolve', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_RedBuff']",
#   "['TFT7_DragonBlue', 1, 'TFT7_Item_WhispersEmblemItem', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_UnstableConcoction']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['53',
#   'TFT6_Augment_Electrocharge2',
#   'TFT6_Augment_Diversify1',
#   'TFT6_Augment_Weakspot',
#   '3',
#   "['TFT7_Thresh', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_RunaansHurricane', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Corki', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_InfinityEdge']",
#   "['TFT7_Sona', 2, 'TFT_Item_RabadonsDeathcap', 'TFT_Item_StatikkShiv', 'TFT_Item_Morellonomicon']",
#   "['TFT7_DragonGold', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff', 'TFT7_Item_ShimmerscaleHeartOfGold']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 4, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['54',
#   'TFT7_Augment_RevelEmblem2',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT7_Augment_RevelPartyFavors',
#   '6',
#   "['TFT7_TahmKench', 2, 'TFT_Item_RecurveBow', 'noItems', 'noItems']",
#   "['TFT7_Jinx', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_WarmogsArmor', 'TFT7_Item_BruiserEmblemItem']",
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 1, 'TFT_Item_Deathblade', 'TFT_Item_PowerGauntlet', 'TFT_Item_Chalice']",
#   "['TFT7_Ornn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_GuinsoosRageblade', 'TFT7_Item_RevelEmblemItem']",
#   "['TFT7_Sona', 1, 'TFT_Item_Morellonomicon', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['55',
#   'TFT6_Augment_TradeSector',
#   'TFT7_Augment_JadeTrait2',
#   'TFT6_Augment_PortableForge',
#   '2',
#   "['TFT7_Karma', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 1, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 1, 'TFT_Item_ZekesHerald', 'TFT_Item_Redemption', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT4_Item_OrnnMuramana', 'TFT_Item_Morellonomicon', 'TFT_Item_ArchangelsStaff']",
#   "['TFT7_Neeko', 2, 'TFT_Item_BrambleVest', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_TitansResolve', 'TFT_Item_TitansResolve']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['56',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT6_Augment_HighEndShopping',
#   'TFT7_Augment_TomeOfTraits2',
#   '8',
#   "['TFT7_Ezreal', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Qiyana', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 1, 'TFT_Item_TitanicHydra', 'TFT7_Item_TempestEmblemItem', 'noItems']",
#   "['TFT7_Ornn', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_TearOfTheGoddess', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_UnstableConcoction', 'TFT7_Item_TempestEmblemItem', 'noItems']",
#   "['TFT7_AoShin', 1, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['57',
#   'TFT6_Augment_TradeSector',
#   'TFT7_Augment_CavalierEmblem',
#   'TFT6_Augment_BlueBattery2',
#   '4',
#   "['TFT7_Sejuani', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_LocketOfTheIronSolari', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Yone', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lillia', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 3, 'TFT_Item_RedBuff', 'TFT_Item_UnstableConcoction', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_SpearOfShojin']",
#   "['TFT7_Yasuo', 1, 'TFT7_Item_CavalierEmblemItem', 'TFT_Item_Quicksilver', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['58',
#   'TFT7_Augment_ScalescornTrait',
#   'TFT6_Augment_ComponentGrabBag',
#   'TFT6_Augment_GrandGambler',
#   '4',
#   "['TFT7_Aatrox', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Leona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yone', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Bloodthirster', 'TFT_Item_Quicksilver']",
#   "['TFT7_Shen', 2, 'TFT_Item_LastWhisper', 'noItems', 'noItems']",
#   "['TFT7_Braum', 3, 'TFT_Item_DragonsClaw', 'noItems', 'noItems']",
#   "['TFT7_Olaf', 2, 'TFT7_Item_AssassinEmblemItem', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Diana', 2, 'TFT_Item_FrozenHeart', 'TFT_Item_RedBuff', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['59',
#   'TFT6_Augment_SecondWind2',
#   'TFT7_Augment_WhispersTrait',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   '5',
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Thresh', 2, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'TFT_Item_TitansResolve', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Bloodthirster']",
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_ZekesHerald', 'TFT_Item_Quicksilver']",
#   "['TFT7_Shyvana', 1, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_IonicSpark', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['60',
#   'TFT7_Augment_JadeTrait',
#   'TFT7_Augment_Preparation2',
#   'TFT7_Augment_UrfsGrabBag1',
#   '6',
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 1, 'TFT_Item_Redemption', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'TFT_Item_LastWhisper', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shyvana', 1, 'TFT_Item_Morellonomicon', 'TFT_Item_ArchangelsStaff', 'TFT_Item_DragonsClaw']",
#   '',
#   '',
#   '',
#   ''],
#  ['61',
#   'TFT7_Augment_TempestEmblem2',
#   'TFT7_Augment_TempestEmblem',
#   'TFT7_Augment_DragonAlliance',
#   '6',
#   "['TFT7_Ezreal', 2, 'TFT_Item_StatikkShiv', 'TFT_Item_RabadonsDeathcap', 'TFT7_Item_ShimmerscaleGoldmancersStaff']",
#   "['TFT7_Ashe', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_LeeSin', 2, 'TFT_Item_RabadonsDeathcap', 'TFT_Item_UnstableConcoction', 'noItems']",
#   "['TFT7_DragonPurple', 1, 'TFT7_Item_TempestEmblemItem', 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_DragonGold', 1, 'TFT7_Item_TempestEmblemItem', 'TFT_Item_DragonsClaw', 'TFT_Item_RedBuff']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['62',
#   'TFT7_Augment_MageEmblem2',
#   'TFT6_Augment_FuturePeepers2',
#   'TFT7_Augment_MysticTrait2',
#   '6',
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'TFT7_Item_MageEmblemItem', 'TFT_Item_Chalice', 'TFT_Item_Chalice']",
#   "['TFT7_Sylas', 2, 'TFT_Item_RedBuff', 'TFT_Item_TitanicHydra', 'noItems']",
#   "['TFT7_Ornn', 2, 'TFT_Item_TitanicHydra', 'TFT_Item_DragonsClaw', 'noItems']",
#   "['TFT7_Sona', 1, 'TFT5_Item_ZephyrRadiant', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 1, 'TFT_Item_SpearOfShojin', 'TFT_Item_InfinityEdge', 'TFT_Item_JeweledGauntlet']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['63',
#   'TFT7_Augment_AxiomArc2',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT7_Augment_BigFriend',
#   '8',
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ryze', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 1, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_TitanicHydra', 'noItems']",
#   "['TFT7_DragonPurple', 1, 'TFT_Item_Bloodthirster', 'TFT_Item_GuardianAngel', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Zoe', 1, 'TFT_Item_ArchangelsStaff', 'TFT_Item_JeweledGauntlet', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_ThiefsGloves', 'TFT_Item_Quicksilver', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Bard', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['64',
#   'TFT7_Augment_GuardianHeroicPresence',
#   'TFT7_Augment_CannoneerRicochet',
#   'TFT6_Augment_GrandGambler',
#   '8',
#   "['TFT7_Leona', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Senna', 2, 'TFT_Item_Quicksilver', 'TFT_Item_GuinsoosRageblade', 'noItems']",
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Thresh', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'TFT_Item_LastWhisper', 'noItems', 'noItems']",
#   "['TFT7_DragonGold', 1, 'TFT7_Item_ShimmerscaleDeterminedInvestor', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['65',
#   'TFT7_Augment_Bloodlust1',
#   'TFT6_Augment_CelestialBlessing1',
#   'TFT7_Augment_ShapeshifterBeastsDen',
#   '7',
#   "['TFT7_Nidalee', 3, 'TFT_Item_Quicksilver', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Deathblade']",
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 1, 'TFT_Item_Redemption', 'TFT_Item_DragonsClaw', 'TFT_Item_TitansResolve']",
#   "['TFT7_DragonGreen', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT_Item_SparringGloves', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['66',
#   'TFT6_Augment_SlowAndSteady',
#   'TFT7_Augment_MageTrait',
#   'TFT6_Augment_PortableForge',
#   '8',
#   "['TFT7_Vladimir', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 3, 'TFT_Item_Chalice', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ryze', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_ArchangelsStaff', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Sylas', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff', 'TFT4_Item_OrnnEternalWinter']",
#   "['TFT7_Illaoi', 2, 'TFT_Item_GiantsBelt', 'noItems', 'noItems']",
#   "['TFT7_Sona', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['67',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT7_Augment_MageConference',
#   'TFT6_Augment_CelestialBlessing2',
#   '6',
#   "['TFT7_Vladimir', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_SpearOfShojin', 'TFT_Item_GuardianAngel']",
#   "['TFT7_Heimerdinger', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nami', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_DragonsClaw', 'TFT_Item_BrambleVest', 'noItems']",
#   "['TFT7_Illaoi', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
# ...
#   "['TFT7_Nidalee', 3, 'TFT_Item_RunaansHurricane', 'TFT_Item_RecurveBow', 'noItems']",
#   "['TFT7_Nami', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ryze', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Varus', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_RunaansHurricane']",
#   "['TFT7_Illaoi', 3, 'TFT_Item_RedBuff', 'TFT_Item_IonicSpark', 'TFT_Item_FrozenHeart']",
#   '',
#   '',
#   '',
#   ''],
#  ['980',
#   'TFT6_Augment_LudensEcho3',
#   'TFT6_Augment_FirstAidKit',
#   'TFT6_Augment_BlueBattery2',
#   '5',
#   "['TFT7_Nami', 2, 'TFT_Item_LocketOfTheIronSolari', 'TFT_Item_StatikkShiv', 'noItems']",
#   "['TFT7_Lillia', 1, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Ryze', 3, 'TFT_Item_JeweledGauntlet', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_SeraphsEmbrace']",
#   "['TFT7_Sylas', 2, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_Zephyr', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'TFT_Item_GuinsoosRageblade', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['981',
#   'TFT7_Augment_Preparation2',
#   'TFT6_Augment_SecondWind2',
#   'TFT6_Augment_CelestialBlessing2',
#   '6',
#   "['TFT7_Taric', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Thresh', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_Bloodthirster', 'noItems']",
#   "['TFT7_Sylas', 1, 'TFT_Item_ZekesHerald', 'TFT_Item_NegatronCloak', 'noItems']",
#   "['TFT7_Anivia', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 1, 'TFT_Item_Redemption', 'TFT_Item_BrambleVest', 'noItems']",
#   "['TFT7_DragonPurple', 1, 'TFT_Item_TitansResolve', 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['982',
#   'TFT6_Augment_LudensEcho2',
#   'TFT7_Augment_WhispersEmblem2',
#   'TFT6_Augment_FuturePeepers',
#   '6',
#   "['TFT7_Taric', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Gnar', 1, 'TFT7_Item_WhispersEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Thresh', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver']",
#   "['TFT7_Sylas', 2, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_PowerGauntlet', 'noItems']",
#   "['TFT7_DragonPurple', 1, 'TFT_Item_RunaansHurricane', 'TFT_Item_Bloodthirster', 'TFT_Item_TitansResolve']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['983',
#   'TFT7_Augment_GuardianEmblem',
#   'TFT6_Augment_SecondWind1',
#   'TFT7_Augment_UrfsGrabBag1',
#   '4',
#   "['TFT7_Leona', 1, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_Sejuani', 2, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 2, 'TFT_Item_PowerGauntlet', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'TFT7_Item_GuardianEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_BrambleVest', 'TFT_Item_GuardianAngel', 'noItems']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_InfinityEdge', 'TFT_Item_UnstableConcoction', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_Redemption', 'TFT7_Item_CavalierEmblemItem', 'TFT_Item_IonicSpark']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['984',
#   'TFT7_Augment_CavalierEmblem',
#   'TFT6_Augment_Electrocharge1',
#   'TFT6_Augment_SecondWind1',
#   '2',
#   "['TFT7_Yone', 1, 'TFT7_Item_CavalierEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Lillia', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Nunu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT7_Item_MirageEmblemItem', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_DragonsClaw']",
#   "['TFT7_DragonBlue', 2, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_ArchangelsStaff', 'TFT_Item_Quicksilver']",
#   "['TFT7_Yasuo', 2, 'TFT7_Item_CavalierEmblemItem', 'TFT_Item_InfinityEdge', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['985',
#   'TFT7_Augment_AFK',
#   'TFT6_Augment_SecondWind1',
#   'TFT7_Augment_UrfsGrabBag1',
#   '4',
#   "['TFT7_Taric', 2, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Gnar', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_RecurveBow', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Neeko', 2, 'TFT_Item_GargoyleStoneplate', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 2, 'TFT_Item_Bloodthirster', 'TFT_Item_TitansResolve', 'TFT_Item_TitansResolve']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_TitansResolve', 'TFT_Item_InfinityEdge', 'TFT_Item_Quicksilver']",
#   "['TFT7_Soraka', 1, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['986',
#   'TFT6_Augment_ThrillOfTheHunt2',
#   'TFT6_Augment_HighEndShopping',
#   'TFT6_Augment_PortableForge',
#   '7',
#   "['TFT7_Sejuani', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Qiyana', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_IonicSpark', 'TFT_Item_Redemption', 'TFT_Item_GiantsBelt']",
#   "['TFT7_Talon', 2, 'TFT_Item_UnstableConcoction', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 1, 'TFT_Item_Quicksilver', 'TFT_Item_GuinsoosRageblade', 'TFT4_Item_OrnnInfinityForce']",
#   "['TFT7_Ornn', 1, 'TFT_Item_Redemption', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['987',
#   'TFT7_Augment_EvokerEssenceTheft',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT6_Augment_PortableForge',
#   '8',
#   "['TFT7_Gnar', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Anivia', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_SpearOfShojin', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Neeko', 1, 'TFT_Item_DragonsClaw', 'TFT_Item_WarmogsArmor', 'noItems']",
#   "['TFT7_DragonGreen', 1, 'TFT_Item_TitansResolve', 'TFT_Item_InfinityEdge', 'TFT4_Item_OrnnDeathsDefiance']",
#   "['TFT7_TrainerDragon', 3, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['988',
#   'TFT6_Augment_CelestialBlessing1',
#   'TFT6_Augment_SecondWind1',
#   'TFT6_Augment_MaxLevel10',
#   '6',
#   "['TFT7_Sett', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Karma', 3, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_SeraphsEmbrace', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Taric', 3, 'TFT_Item_FrozenHeart', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 1, 'TFT_Item_Chalice', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 1, 'TFT_Item_Deathblade', 'TFT_Item_Bloodthirster', 'TFT_Item_GiantsBelt']",
#   "['TFT7_Zoe', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['989',
#   'TFT6_Augment_JeweledLotus',
#   'TFT6_Augment_FirstAidKit',
#   'TFT7_Augment_JadeEternalProtection',
#   '8',
#   "['TFT7_Karma', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ezreal', 3, 'TFT_Item_InfinityEdge', 'TFT_Item_TearOfTheGoddess', 'noItems']",
#   "['TFT7_Leona', 3, 'TFT_Item_GargoyleStoneplate', 'TFT_Item_Quicksilver', 'noItems']",
#   "['TFT7_Taric', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_ZekesHerald', 'noItems', 'noItems']",
#   "['TFT7_LeeSin', 1, 'TFT_Item_InfinityEdge', 'noItems', 'noItems']",
#   "['TFT7_Soraka', 1, 'TFT_Item_NeedlesslyLargeRod', 'TFT_Item_SpearOfShojin', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['990',
#   'TFT6_Augment_MaxLevel10',
#   'TFT7_Augment_ShimmerscaleEmblem',
#   'TFT6_Augment_MakeshiftArmor2',
#   '1',
#   "['TFT7_Sylas', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Talon', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ornn', 2, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_WarmogsArmor', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Bard', 2, 'TFT7_Item_ShimmerscaleEmblemItem', 'TFT_Item_PowerGauntlet', 'TFT_Item_Chalice']",
#   "['TFT7_AoShin', 2, 'TFT_Item_SpearOfShojin', 'TFT_Item_ArchangelsStaff', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Pyke', 1, 'TFT_Item_ThiefsGloves', 'TFT_Item_StatikkShiv', 'TFT_Item_RabadonsDeathcap']",
#   "['TFT7_Soraka', 2, 'TFT7_Item_MageEmblemItem', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['991',
#   'TFT7_Augment_RevelTrait',
#   'TFT6_Augment_Featherweights1',
#   'TFT7_Augment_AxiomArc2',
#   '8',
#   "['TFT7_Heimerdinger', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_TahmKench', 2, 'TFT_Item_ChainVest', 'noItems', 'noItems']",
#   "['TFT7_Jinx', 2, 'TFT_Item_StatikkShiv', 'noItems', 'noItems']",
#   "['TFT7_Tristana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Corki', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonBlue', 1, 'TFT_Item_InfinityEdge', 'TFT_Item_JeweledGauntlet', 'TFT_Item_TitansResolve']",
#   "['TFT7_TrainerDragon', 2, 'TFT7_Item_TrainerSnax', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['992',
#   'TFT6_Augment_TradeSector',
#   'TFT6_Augment_Diversify1',
#   'TFT6_Augment_SunfireBoard',
#   '6',
#   "['TFT7_Qiyana', 2, 'TFT_Item_SeraphsEmbrace', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT_Item_LocketOfTheIronSolari', 'noItems', 'noItems']",
#   "['TFT7_Twitch', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Hecarim', 2, 'TFT_Item_ChainVest', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'TFT_Item_Deathblade', 'TFT_Item_Bloodthirster', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Ornn', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shyvana', 1, 'TFT_Item_RedBuff', 'TFT_Item_FrozenHeart', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['993',
#   'TFT6_Augment_TradeSector',
#   'TFT6_Augment_SunfireBoard',
#   'TFT7_Augment_GuardianHeroicPresence',
#   '5',
#   "['TFT7_Karma', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ezreal', 3, 'TFT_Item_HextechGunblade', 'TFT_Item_ArchangelsStaff', 'TFT_Item_ArchangelsStaff']",
#   "['TFT7_Leona', 3, 'TFT_Item_WarmogsArmor', 'TFT_Item_DragonsClaw', 'noItems']",
#   "['TFT7_Taric', 3, 'TFT_Item_TitanicHydra', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_Zephyr', 'noItems', 'noItems']",
#   "['TFT7_LeeSin', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['994',
#   'TFT6_Augment_CelestialBlessing2',
#   'TFT6_Augment_Ascension',
#   'TFT6_Augment_FirstAidKit',
#   '4',
#   "['TFT7_Lulu', 2, 'TFT_Item_LocketOfTheIronSolari', 'noItems', 'noItems']",
#   "['TFT7_Neeko', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ornn', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sona', 1, 'TFT_Item_Shroud', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 1, 'TFT_Item_IonicSpark', 'TFT_Item_WarmogsArmor', 'TFT_Item_RedBuff']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 1, 'TFT_Item_SpearOfShojin', 'TFT_Item_ArchangelsStaff', 'noItems']",
#   "['TFT7_Soraka', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['995',
#   'TFT6_Augment_SecondWind1',
#   'TFT6_Augment_RadiantRelics',
#   'TFT6_Augment_WindfallPlusPlus',
#   '3',
#   "['TFT7_Lulu', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Sylas', 2, 'TFT_Item_Redemption', 'TFT_Item_IonicSpark', 'noItems']",
#   "['TFT7_Ornn', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_Sona', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 1, 'TFT_Item_MadredsBloodrazor', 'noItems', 'noItems']",
#   "['TFT7_Zoe', 2, 'TFT5_Item_TitansResolveRadiant', 'TFT_Item_MadredsBloodrazor', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_AoShin', 2, 'TFT7_Item_MageEmblemItem', 'TFT_Item_JeweledGauntlet', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Pyke', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ['996',
#   'TFT6_Augment_LudensEcho2',
#   'TFT6_Augment_ItemGrabBag1',
#   'TFT6_Augment_CyberneticImplants1',
#   '6',
#   "['TFT7_Sett', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Kayn', 3, 'TFT_Item_InfinityEdge', 'TFT_Item_RedBuff', 'TFT_Item_HextechGunblade']",
#   "['TFT7_Qiyana', 3, 'TFT_Item_IonicSpark', 'TFT_Item_UnstableConcoction', 'TFT_Item_UnstableConcoction']",
#   "['TFT7_LeeSin', 2, 'TFT_Item_RedBuff', 'noItems', 'noItems']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Diana', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Pyke', 1, 'TFT_Item_InfinityEdge', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['997',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT7_Augment_Preparation2',
#   'TFT6_Augment_VerdantVeil',
#   '5',
#   "['TFT7_Nidalee', 3, 'TFT_Item_UnstableConcoction', 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Deathblade']",
#   "['TFT7_Gnar', 3, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Elise', 2, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Deathblade', 'TFT_Item_UnstableConcoction']",
#   "['TFT7_Neeko', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonPurple', 2, 'TFT_Item_DragonsClaw', 'TFT_Item_GuardianAngel', 'noItems']",
#   "['TFT7_Ornn', 2, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['998',
#   'TFT6_Augment_ThrillOfTheHunt1',
#   'TFT6_Augment_RichGetRicherPlus',
#   'TFT7_Augment_Preparation3',
#   '8',
#   "['TFT7_Karma', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ezreal', 2, 'TFT_Item_ArchangelsStaff', 'TFT_Item_BFSword', 'noItems']",
#   "['TFT7_Leona', 3, 'TFT_Item_BrambleVest', 'TFT_Item_GiantsBelt', 'noItems']",
#   "['TFT7_Taric', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['999',
#   'TFT7_Augment_ThinkFast',
#   'TFT7_Augment_BandOfThieves1',
#   'TFT7_Augment_TempestEmblem2',
#   '3',
#   "['TFT7_Karma', 2, 'TFT7_Item_TempestEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Ezreal', 3, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_ArchangelsStaff', 'TFT_Item_UnstableConcoction']",
#   "['TFT7_Leona', 3, 'TFT_Item_RedBuff', 'TFT7_Item_TempestEmblemItem', 'TFT_Item_DragonsClaw']",
#   "['TFT7_Taric', 3, 'TFT_Item_ThiefsGloves', 'TFT_Item_StatikkShiv', 'TFT_Item_GuinsoosRageblade']",
#   "['TFT7_Ashe', 2, 'TFT_Item_ThiefsGloves', 'TFT_Item_WarmogsArmor', 'TFT_Item_DragonsClaw']",
#   "['TFT7_Qiyana', 2, 'TFT_Item_Shroud', 'TFT_Item_StatikkShiv', 'noItems']",
#   "['TFT7_LeeSin', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Ornn', 1, 'TFT_Item_BrambleVest', 'TFT_Item_GuardianAngel', 'noItems']",
#   '',
#   '',
#   '',
#   ''],
#  ['1000',
#   'TFT6_Augment_TradeSector',
#   'TFT7_Augment_RagewingEmblem',
#   'TFT6_Augment_CelestialBlessing2',
#   '7',
#   "['TFT7_Sett', 3, 'TFT_Item_GuinsoosRageblade', 'TFT_Item_Quicksilver', 'TFT_Item_MadredsBloodrazor']",
#   "['TFT7_Kayn', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Shen', 2, 'TFT7_Item_TempestEmblemItem', 'TFT_Item_GargoyleStoneplate', 'TFT_Item_FrozenHeart']",
#   "['TFT7_Olaf', 1, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_LeeSin', 2, 'TFT7_Item_RagewingEmblemItem', 'TFT_Item_SeraphsEmbrace', 'TFT_Item_JeweledGauntlet']",
#   "['TFT7_Swain', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Xayah', 2, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['1001',
#   'TFT6_Augment_RichGetRicher',
#   'TFT7_Augment_SwiftshotEmblem',
#   'TFT6_Augment_ComponentGrabBag',
#   '2',
#   "['TFT7_Karma', 3, 'TFT7_Item_SwiftshotEmblemItem', 'noItems', 'noItems']",
#   "['TFT7_Ezreal', 3, 'TFT_Item_MadredsBloodrazor', 'TFT_Item_Bloodthirster', 'TFT_Item_Deathblade']",
#   "['TFT7_Leona', 3, 'TFT_Item_BrambleVest', 'TFT_Item_Quicksilver', 'noItems']",
#   "['TFT7_Taric', 3, 'TFT_Item_TitanicHydra', 'noItems', 'noItems']",
#   "['TFT7_Ashe', 2, 'TFT_Item_ZekesHerald', 'TFT_Item_ZekesHerald', 'TFT_Item_ZekesHerald']",
#   "['TFT7_Varus', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_DragonGreen', 2, 'noItems', 'noItems', 'noItems']",
#   "['TFT7_Yasuo', 2, 'TFT_Item_RunaansHurricane', 'noItems', 'noItems']",
#   "['TFT7_Bard', 1, 'noItems', 'noItems', 'noItems']",
#   '',
#   '',
#   ''],
#  ...]
